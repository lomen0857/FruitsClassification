# %%
import os
import glob
import pickle
import shap

import pandas as pd
import numpy as np
import category_encoders as ce
import tensorflow as tf

from numpy import argmax
from PIL import Image

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import *
from keras.layers import *
from keras.models import *
from keras.utils import to_categorical
from keras.applications.vgg16 import VGG16

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
font = {'family' : 'meiryo'}
plt.rc('font', **font)

# %%
train_path = "./fruits-360/Training/"

file_list = []
Y = []
for dir_name in os.listdir(train_path):
    if "Apple" in dir_name:
        for file_name in os.listdir(train_path + dir_name):
            Y.append(dir_name)
            file_list.append(train_path + dir_name + "/" + file_name)

# %%
image_size=80
X=[]

for image_path in file_list:
    #画像ファイル取得
    img_file = glob.glob(image_path)
    if not img_file:
        print(image_path)
        continue
    image = Image.open(img_file[0])
    image = image.convert("RGB")
    image = image.resize((image_size, image_size))
    X.append(np.array(image))
    
del image

# %%
def create_model():
    model = Sequential()
    model.add(Conv2D(16, kernel_size = 3, activation="relu", input_shape=(image_size,image_size,3)))
    model.add(Conv2D(16, kernel_size = 3, activation="relu"))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(32, kernel_size = 3, activation="relu"))
    model.add(Conv2D(32, kernel_size = 3, activation="relu"))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(64, kernel_size = 3, activation="relu"))
    model.add(Conv2D(64, kernel_size = 3, activation="relu"))
    #model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(128, activation="relu"))
    #model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(13, activation='softmax'))
    return model

# %%
def create_model_vgg():
    #base_model=VGG16(weights='imagenet',include_top=False,
    #             input_tensor=Input(shape=(image_size,image_size,3)))
    base_model=VGG16(weights='imagenet',include_top=False,
                 input_shape=(image_size,image_size,3))
    x = base_model.output
    x = BatchNormalization()(x)
    x = Flatten()(x)
    x = Dense(128,activation='relu')(x)
    x = Dropout(0.2)(x)
    prediction = Dense(13, activation='softmax')(x)

    for layer in base_model.layers[:15]:
        layer.trainable=False
    
    return Model(inputs=base_model.input,outputs=prediction)

# %%
def model_train(X, Y):
    
    X = np.array(X).astype("float32") / 255
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
    for fold, (train_index, test_index) in enumerate(skf.split(X,Y)):
        
        print('#'*25)
        print('### FOLD %i'%(fold+1))
        print('#'*25)
        
        ce_ohe = ce.OneHotEncoder(handle_unknown='impute')
        Y = np.array(ce_ohe.fit_transform(Y))
        
        X_train = X[train_index]
        X_valid = X[test_index]
        Y_train = Y[train_index]
        Y_valid = Y[test_index]
    
        datagen = ImageDataGenerator(
                featurewise_center=False,  # set input mean to 0 over the dataset
                samplewise_center=False,  # set each sample mean to 0
                featurewise_std_normalization=False,  # divide inputs by std of the dataset
                samplewise_std_normalization=False,  # divide each input by its std
                zca_whitening=False,  # apply ZCA whitening
                rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
                zoom_range = 0.1, # Randomly zoom image 
                width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
                height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
                horizontal_flip=False,  # randomly flip images
                vertical_flip=False)  # randomly flip images

        datagen.fit(X_train)

        sess = tf.InteractiveSession()

        model = create_model()
        model.compile(loss='categorical_crossentropy', optimizer="rmsprop", metrics=['accuracy'])
        model.summary()

        #callbacks = [ReduceLROnPlateau(monitor='loss', patience=4, verbose=1, factor=0.6),
        #         EarlyStopping(monitor='loss', patience=10)]

        #hist = model.fit(X_train, y_train, epochs=10, batch_size=64,verbose=1,callbacks=callbacks)
        learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                                patience=3, 
                                                verbose=1, 
                                                factor=0.5, 
                                                min_lr=0.00001)

        print(X_train.shape)
        print(Y_train.shape)
        
        hist = model.fit_generator(datagen.flow(X_train,Y_train, batch_size=64),
                                  epochs = 15, validation_data = (X_valid,Y_valid),
                                  verbose = 2, steps_per_epoch=X_train.shape[0] // 64
                                  , callbacks=[learning_rate_reduction])


        pickle.dump(model,open("model/model_" + str(fold) + ".sav","wb"))
        pickle.dump(hist,open("model/hist_" + str(fold) + ".sav","wb"))


        pred = model.predict(X_valid)
        pred = argmax(pred, axis=1)
        Y_valid = argmax(Y_valid, axis=1)
        ACC_pred = accuracy_score(pred, Y_valid)

        fig = plt.figure(figsize=(12, 16))
        fig.subplots_adjust(wspace=0.5)
        fig.suptitle("hist", fontsize=20)

        ax1 = fig.add_subplot(211,
                              title="Loss:",
                              ylabel="Loss",
                              xlabel="Epoch")
        ax1.plot(hist.history["loss"])
        ax1.legend(["Train", "Test"], loc="upper left")

        ax2 = fig.add_subplot(212,
                              title="val Acc:",
                              ylabel="val Acc",
                              xlabel="Epoch")
        ax2.plot(hist.history['val_accuracy'])
        ax2.legend(["Train", "Test"], loc="upper left")

        plt.show()


        with tf.Session() as sess:
             sess.run(tf.global_variables_initializer())
        
        #explainer = shap.DeepExplainer(model, (X_train[0:200]))
        #for i in range(3):
        #    shap_values = explainer.shap_values(X_valid[[i]])
        #    shap.image_plot(shap_values, X_valid[[i]])
        #    plt.gcf().set_size_inches(20, 20)

        print('>>>> FOLD %i val Acc ='%(fold+1), ACC_pred)
        print()

# %%
with tf.Session() as sess:
     sess.run(tf.global_variables_initializer())

# %%
model_train(X,Y)
# Out:
# #########################
# ### FOLD 1
# #########################
# An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 78, 78, 16)        448
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 76, 76, 16)        2320
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 38, 38, 16)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 36, 36, 32)        4640
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 17, 17, 32)        0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               295040
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 13)                1677
# =================================================================
# Total params: 368,797
# Trainable params: 368,797
# Non-trainable params: 0
# _________________________________________________________________
# (5123, 80, 80, 3)
# (5123, 13)
# Epoch 1/15
#  - 8s - loss: 1.7871 - accuracy: 0.3501 - val_loss: 1.1657 - val_accuracy: 0.5410
# Epoch 2/15
#  - 8s - loss: 1.0263 - accuracy: 0.6090 - val_loss: 0.6322 - val_accuracy: 0.8267
# Epoch 3/15
#  - 8s - loss: 0.7035 - accuracy: 0.7365 - val_loss: 0.4697 - val_accuracy: 0.8267
# Epoch 4/15
#  - 8s - loss: 0.4789 - accuracy: 0.8179 - val_loss: 0.1351 - val_accuracy: 0.9336
# Epoch 5/15
#  - 8s - loss: 0.3953 - accuracy: 0.8549 - val_loss: 0.1050 - val_accuracy: 0.9711
# Epoch 6/15
#  - 8s - loss: 0.2699 - accuracy: 0.8976 - val_loss: 0.0765 - val_accuracy: 0.9805
# Epoch 7/15
#  - 8s - loss: 0.2656 - accuracy: 0.9067 - val_loss: 0.0479 - val_accuracy: 0.9945
# Epoch 8/15
#  - 8s - loss: 0.2099 - accuracy: 0.9271 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 9/15
#  - 8s - loss: 0.1657 - accuracy: 0.9478 - val_loss: 0.0185 - val_accuracy: 0.9969
# Epoch 10/15
#  - 8s - loss: 0.1531 - accuracy: 0.9500 - val_loss: 0.6710 - val_accuracy: 0.8829
# Epoch 11/15
#  - 8s - loss: 0.1496 - accuracy: 0.9563 - val_loss: 0.0148 - val_accuracy: 1.0000
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/15
#  - 7s - loss: 0.0407 - accuracy: 0.9864 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 13/15
#  - 8s - loss: 0.0298 - accuracy: 0.9895 - val_loss: 0.0026 - val_accuracy: 0.9992
# Epoch 14/15
#  - 8s - loss: 0.0355 - accuracy: 0.9892 - val_loss: 0.0643 - val_accuracy: 0.9758
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/15
#  - 8s - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0189 - val_accuracy: 0.9922
# >>>> FOLD 1 val Acc = 0.9921935987509758
#
# #########################
# ### FOLD 2
# #########################
# An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_49 (Conv2D)           (None, 78, 78, 16)        448
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 76, 76, 16)        2320
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 38, 38, 16)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 36, 36, 32)        4640
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 17, 17, 32)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               295040
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 13)                1677
# =================================================================
# Total params: 368,797
# Trainable params: 368,797
# Non-trainable params: 0
# _________________________________________________________________
# (5123, 80, 80, 3)
# (5123, 13)
# Epoch 1/15
#  - 8s - loss: 1.8028 - accuracy: 0.3603 - val_loss: 0.9786 - val_accuracy: 0.6885
# Epoch 2/15
#  - 8s - loss: 0.9529 - accuracy: 0.6262 - val_loss: 0.4455 - val_accuracy: 0.8400
# Epoch 3/15
#  - 8s - loss: 0.6021 - accuracy: 0.7654 - val_loss: 0.2737 - val_accuracy: 0.9173
# Epoch 4/15
#  - 8s - loss: 0.4465 - accuracy: 0.8302 - val_loss: 0.1854 - val_accuracy: 0.9508
# Epoch 5/15
#  - 8s - loss: 0.3265 - accuracy: 0.8772 - val_loss: 0.1697 - val_accuracy: 0.9227
# Epoch 6/15
#  - 8s - loss: 0.2911 - accuracy: 0.8976 - val_loss: 0.0880 - val_accuracy: 0.9859
# Epoch 7/15
#  - 8s - loss: 0.2513 - accuracy: 0.9130 - val_loss: 0.0332 - val_accuracy: 0.9930
# Epoch 8/15
#  - 8s - loss: 0.2085 - accuracy: 0.9301 - val_loss: 0.0375 - val_accuracy: 0.9969
# Epoch 9/15
#  - 8s - loss: 0.1735 - accuracy: 0.9450 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 10/15
#  - 8s - loss: 0.1726 - accuracy: 0.9514 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 11/15
#  - 8s - loss: 0.1188 - accuracy: 0.9632 - val_loss: 0.0627 - val_accuracy: 0.9696
# Epoch 12/15
#  - 8s - loss: 0.1281 - accuracy: 0.9615 - val_loss: 0.3182 - val_accuracy: 0.9126
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/15
#  - 8s - loss: 0.0367 - accuracy: 0.9899 - val_loss: 7.0259e-04 - val_accuracy: 1.0000
# Epoch 14/15
#  - 8s - loss: 0.0327 - accuracy: 0.9891 - val_loss: 7.2041e-04 - val_accuracy: 1.0000
# Epoch 15/15
#  - 8s - loss: 0.0319 - accuracy: 0.9923 - val_loss: 5.5594e-04 - val_accuracy: 1.0000
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# >>>> FOLD 2 val Acc = 1.0
#
# #########################
# ### FOLD 3
# #########################
# An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_55 (Conv2D)           (None, 78, 78, 16)        448
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 76, 76, 16)        2320
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 38, 38, 16)        0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 36, 36, 32)        4640
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 17, 17, 32)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               295040
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 13)                1677
# =================================================================
# Total params: 368,797
# Trainable params: 368,797
# Non-trainable params: 0
# _________________________________________________________________
# (5123, 80, 80, 3)
# (5123, 13)
# Epoch 1/15
#  - 8s - loss: 1.8566 - accuracy: 0.3520 - val_loss: 0.9940 - val_accuracy: 0.6604
# Epoch 2/15
#  - 8s - loss: 0.9876 - accuracy: 0.6296 - val_loss: 1.1520 - val_accuracy: 0.5238
# Epoch 3/15
#  - 8s - loss: 0.7564 - accuracy: 0.7199 - val_loss: 0.4479 - val_accuracy: 0.8205
# Epoch 4/15
#  - 8s - loss: 0.5392 - accuracy: 0.7984 - val_loss: 0.2760 - val_accuracy: 0.9149
# Epoch 5/15
#  - 9s - loss: 0.4343 - accuracy: 0.8541 - val_loss: 0.0823 - val_accuracy: 0.9727
# Epoch 6/15
#  - 9s - loss: 0.3075 - accuracy: 0.8885 - val_loss: 0.0495 - val_accuracy: 0.9945
# Epoch 7/15
#  - 9s - loss: 0.3133 - accuracy: 0.8992 - val_loss: 0.2202 - val_accuracy: 0.9133
# Epoch 8/15
#  - 9s - loss: 0.2420 - accuracy: 0.9275 - val_loss: 0.0151 - val_accuracy: 0.9961
# Epoch 9/15
#  - 9s - loss: 0.2067 - accuracy: 0.9322 - val_loss: 0.0303 - val_accuracy: 0.9945
# Epoch 10/15
#  - 8s - loss: 0.1751 - accuracy: 0.9538 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 11/15
#  - 9s - loss: 0.1697 - accuracy: 0.9624 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 12/15
#  - 8s - loss: 0.1679 - accuracy: 0.9492 - val_loss: 0.0203 - val_accuracy: 0.9945
# Epoch 13/15
#  - 9s - loss: 0.1447 - accuracy: 0.9646 - val_loss: 0.0016 - val_accuracy: 1.0000
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 14/15
#  - 8s - loss: 0.0359 - accuracy: 0.9884 - val_loss: 7.3558e-04 - val_accuracy: 1.0000
# Epoch 15/15
#  - 9s - loss: 0.0453 - accuracy: 0.9907 - val_loss: 7.5019e-04 - val_accuracy: 1.0000
# >>>> FOLD 3 val Acc = 1.0
#
# #########################
# ### FOLD 4
# #########################
# An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_61 (Conv2D)           (None, 78, 78, 16)        448
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 76, 76, 16)        2320
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 38, 38, 16)        0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 36, 36, 32)        4640
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 17, 17, 32)        0
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               295040
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 13)                1677
# =================================================================
# Total params: 368,797
# Trainable params: 368,797
# Non-trainable params: 0
# _________________________________________________________________
# (5123, 80, 80, 3)
# (5123, 13)
# Epoch 1/15
#  - 9s - loss: 1.7640 - accuracy: 0.3655 - val_loss: 1.1832 - val_accuracy: 0.5402
# Epoch 2/15
#  - 9s - loss: 0.9256 - accuracy: 0.6519 - val_loss: 1.1659 - val_accuracy: 0.5792
# Epoch 3/15
#  - 9s - loss: 0.6289 - accuracy: 0.7517 - val_loss: 0.4396 - val_accuracy: 0.7931
# Epoch 4/15
#  - 9s - loss: 0.4855 - accuracy: 0.8138 - val_loss: 0.3396 - val_accuracy: 0.8946
# Epoch 5/15
#  - 8s - loss: 0.3819 - accuracy: 0.8640 - val_loss: 0.1667 - val_accuracy: 0.9422
# Epoch 6/15
#  - 8s - loss: 0.3125 - accuracy: 0.9031 - val_loss: 0.0560 - val_accuracy: 0.9992
# Epoch 7/15
#  - 9s - loss: 0.2479 - accuracy: 0.9097 - val_loss: 0.0645 - val_accuracy: 0.9867
# Epoch 8/15
#  - 9s - loss: 0.2138 - accuracy: 0.9397 - val_loss: 0.2740 - val_accuracy: 0.9040
# Epoch 9/15
#  - 8s - loss: 0.1770 - accuracy: 0.9435 - val_loss: 0.4983 - val_accuracy: 0.8259
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 10/15
#  - 8s - loss: 0.0689 - accuracy: 0.9759 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 11/15
#  - 9s - loss: 0.0447 - accuracy: 0.9867 - val_loss: 0.0014 - val_accuracy: 0.9992
# Epoch 12/15
#  - 8s - loss: 0.0535 - accuracy: 0.9854 - val_loss: 9.3674e-04 - val_accuracy: 1.0000
# Epoch 13/15
#  - 9s - loss: 0.0506 - accuracy: 0.9858 - val_loss: 2.8266e-04 - val_accuracy: 1.0000
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 14/15
#  - 9s - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 15/15
#  - 9s - loss: 0.0143 - accuracy: 0.9955 - val_loss: 1.3275e-04 - val_accuracy: 1.0000
# >>>> FOLD 4 val Acc = 1.0
#
# #########################
# ### FOLD 5
# #########################
# An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_67 (Conv2D)           (None, 78, 78, 16)        448
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 76, 76, 16)        2320
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 38, 38, 16)        0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 36, 36, 32)        4640
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 17, 17, 32)        0
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               295040
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 13)                1677
# =================================================================
# Total params: 368,797
# Trainable params: 368,797
# Non-trainable params: 0
# _________________________________________________________________
# (5124, 80, 80, 3)
# (5124, 13)
# Epoch 1/15
#  - 9s - loss: 1.7534 - accuracy: 0.3792 - val_loss: 0.9516 - val_accuracy: 0.6852
# Epoch 2/15
#  - 10s - loss: 0.9152 - accuracy: 0.6569 - val_loss: 0.4753 - val_accuracy: 0.8414
# Epoch 3/15
#  - 9s - loss: 0.6467 - accuracy: 0.7569 - val_loss: 0.2582 - val_accuracy: 0.9234
# Epoch 4/15
#  - 9s - loss: 0.4631 - accuracy: 0.8271 - val_loss: 0.4563 - val_accuracy: 0.7930
# Epoch 5/15
#  - 9s - loss: 0.3729 - accuracy: 0.8696 - val_loss: 0.0895 - val_accuracy: 0.9859
# Epoch 6/15
#  - 9s - loss: 0.3266 - accuracy: 0.8838 - val_loss: 0.1279 - val_accuracy: 0.9609
# Epoch 7/15
#  - 9s - loss: 0.2315 - accuracy: 0.9186 - val_loss: 0.2155 - val_accuracy: 0.8938
# Epoch 8/15
#  - 9s - loss: 0.2322 - accuracy: 0.9209 - val_loss: 0.0569 - val_accuracy: 0.9844
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/15
#  - 9s - loss: 0.0745 - accuracy: 0.9711 - val_loss: 0.0588 - val_accuracy: 0.9875
# Epoch 10/15
#  - 9s - loss: 0.0683 - accuracy: 0.9759 - val_loss: 0.0201 - val_accuracy: 0.9930
# Epoch 11/15
#  - 9s - loss: 0.0569 - accuracy: 0.9798 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 12/15
#  - 9s - loss: 0.0560 - accuracy: 0.9810 - val_loss: 0.0280 - val_accuracy: 0.9875
# Epoch 13/15
#  - 10s - loss: 0.0452 - accuracy: 0.9842 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 14/15
#  - 8s - loss: 0.0538 - accuracy: 0.9854 - val_loss: 0.0032 - val_accuracy: 1.0000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/15
#  - 9s - loss: 0.0190 - accuracy: 0.9925 - val_loss: 0.0614 - val_accuracy: 0.9734
# >>>> FOLD 5 val Acc = 0.9734375

# %%
file_list = []
test_path = "./fruits-360/Test/"
Y_test = []

for dir_name in os.listdir(test_path):
    if "Apple" in dir_name:
        for file_name in os.listdir(test_path + dir_name):
            Y_test.append(dir_name)
            file_list.append(test_path + dir_name + "/" + file_name)

# %%
image_size=80
X_test = []

for image_path in file_list:
    #画像ファイル取得
    img_file = glob.glob(image_path)
    if not img_file:
        print(image_path)
        continue
    image = Image.open(img_file[0])
    image = image.convert("RGB")
    image = image.resize((image_size, image_size))
    X_test.append(np.array(image))
    
del image

# %%
X_test = np.array(X_test).astype("float32") / 255
ce_ohe = ce.OneHotEncoder(handle_unknown='impute')
Y_test = np.array(ce_ohe.fit_transform(Y_test))

# %%
pred = np.zeros((len(X_test),13))

for i in range(5):
    print(i)
    model = pickle.load(open("model/model_"+ str(i) +".sav","rb"))
    temp = model.predict(X_test)
    pred += temp
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
Y_pred = argmax(pred, axis=1)
Y_true = argmax(Y_test, axis=1)
ACC_pred = accuracy_score(Y_pred, Y_true)
print('>>>> val Acc =', ACC_pred)
# Out:
# >>>> val Acc = 1.0

# %%
X_test.shape
# Out:
# (2134, 80, 80, 3)

# %%
#Y_pred_classes = np.argmax(pred,axis = 1) 
#Y_true = np.argmax(Y_val,axis = 1)

# %%
errors = (Y_pred - Y_true != 0)

Y_pred_classes_errors = Y_pred[errors]
Y_pred_errors = pred[errors]
Y_true_errors = Y_true[errors]
X_val_errors = X_test[errors]

# %%
def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 10 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 5
    fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(20, 8))
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[error]).reshape((image_size,image_size,3)))
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[error],obs_errors[error]))
            n += 1
    plt.show()
    
Y_pred_errors_prob = np.max(Y_pred_errors,axis = 1)
true_prob_errors = np.diagonal(np.take(Y_pred_errors, Y_true_errors, axis=1))
delta_pred_true_errors = Y_pred_errors_prob - true_prob_errors
sorted_dela_errors = np.argsort(delta_pred_true_errors)
most_important_errors = sorted_dela_errors[-10:]

display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-d9f57ab4a4a8> in <module>
#      19 most_important_errors = sorted_dela_errors[-10:]
#      20
# ---> 21 display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)
#
# <ipython-input-105-d9f57ab4a4a8> in display_errors(errors_index, img_errors, pred_errors, obs_errors)
#       7     for row in range(nrows):
#       8         for col in range(ncols):
# ----> 9             error = errors_index[n]
#      10             ax[row,col].imshow((img_errors[error]).reshape((image_size,image_size,3)))
#      11             ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[error],obs_errors[error]))
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
np.array(X).shape
# Out:
# (6404, 80, 80, 3)

# %%
#When describing Deep Learning, we use DeepExplainer.
explainer = shap.DeepExplainer(model, (np.array(X)[0:100]))

#Check out the 10 data that the model has mistakenly predicted.
for i in most_important_errors:
    
    #Calculates the SHAP value.
    shap_values = explainer.shap_values(X_val_errors[[i]])
    
    #The following two lines are extras. It works even if you turn it off.
    index_names = np.array([str(x) + "\n" + '{:>7.3%}'.format(Y_pred_errors[i][x]) for x in range(10)]).reshape(1,10)
    print("Predicted label :{}\nTrue label :{}".format(Y_pred_classes_errors[i],Y_true_errors[i]))
    
    #Displays the results.
    shap.image_plot(shap_values, X_val_errors[[i]] ,index_names ,show=False)
    plt.show()

# %%
model = pickle.load(open("model/model.sav","rb"))
hist = pickle.load(open("model/hist.sav","rb"))

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
y_train.shape
# Out:
# (5123, 13)

# %%
pred = model.predict(X_valid)
pred = argmax(pred, axis=1)
y_valid = argmax(y_valid, axis=1)
ACC_pred = accuracy_score(pred, y_valid)

# %%
fig = plt.figure(figsize=(12, 16))
fig.subplots_adjust(wspace=0.5)
fig.suptitle("predict", fontsize=20)

ax1 = fig.add_subplot(211,
                      title="Loss",
                      ylabel="Loss",
                      xlabel="Epoch")
ax1.plot(hist.history["loss"])
ax1.legend(["Train", "Test"], loc="upper left")

ax2 = fig.add_subplot(212,
                      title="val Acc:" + str(ACC_pred)[:5] ,
                      ylabel="val Acc",
                      xlabel="Epoch")
ax2.plot(hist.history['val_accuracy'])
ax2.legend(["Train", "Test"], loc="upper left")

plt.show()


#explainer = shap.DeepExplainer(model, (X_train[0:200]))
#for i in range(3):
#    shap_values = explainer.shap_values(X_valid[[i]])
#    shap.image_plot(shap_values, X_valid[[i]])
#    plt.gcf().set_size_inches(20, 20)
